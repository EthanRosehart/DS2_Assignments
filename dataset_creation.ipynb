# %% [markdown]
# # Journal Entries
# * We have journal entries in 18 emotions
# * We need to consolidate into the core 5 emotions

# %%
import pandas as pd
import numpy as np

# %%
df_journals = pd.read_csv('https://media.githubusercontent.com/media/EthanRosehart/DS2_Assignments/refs/heads/main/students_journal.csv')

# %%
df_journals.head()
# Out:
#                                               Answer  Answer.f1.afraid.raw  \
# 0  My family was the most salient part of my day,...                 False
# 1  Yoga keeps me focused. I am able to take some ...                 False
# 2  Yesterday, my family and I played a bunch of b...                 False
# 3  Yesterday, I visited my parents and had dinner...                 False
# 4  Yesterday, I really felt the importance of my ...                 False
#
#    Answer.f1.angry.raw  Answer.f1.anxious.raw  Answer.f1.ashamed.raw  \
# 0                False                   True                  False
# 1                False                  False                  False
# 2                False                  False                  False
# 3                False                  False                  False
# 4                False                  False                  False
#
#    Answer.f1.awkward.raw  Answer.f1.bored.raw  Answer.f1.calm.raw  \
# 0                  False                False               False
# 1                  False                False                True
# 2                  False                False                True
# 3                  False                False                True
# 4                  False                False               False
#
#    Answer.f1.confused.raw  Answer.f1.disgusted.raw  ...  Answer.t1.family.raw  \
# 0                   False                    False  ...                  True
# 1                   False                    False  ...                 False
# 2                   False                    False  ...                  True
# 3                   False                    False  ...                  True
# 4                   False                    False  ...                 False
#
#    Answer.t1.food.raw  Answer.t1.friends.raw  Answer.t1.god.raw  \
# 0               False                  False              False
# 1               False                  False              False
# 2               False                  False              False
# 3               False                  False              False
# 4               False                  False              False
#
#    Answer.t1.health.raw  Answer.t1.love.raw  Answer.t1.recreation.raw  \
# 0                 False               False                     False
# 1                 False               False                     False
# 2                 False               False                     False
# 3                 False               False                     False
# 4                  True               False                     False
#
#    Answer.t1.school.raw  Answer.t1.sleep.raw  Answer.t1.work.raw
# 0                 False                False               False
# 1                 False                False               False
# 2                 False                False               False
# 3                 False                False               False
# 4                 False                False               False
#
# [5 rows x 30 columns]

# %%
df_journals.columns
# Out:
# Index(['Answer', 'Answer.f1.afraid.raw', 'Answer.f1.angry.raw',
#        'Answer.f1.anxious.raw', 'Answer.f1.ashamed.raw',
#        'Answer.f1.awkward.raw', 'Answer.f1.bored.raw', 'Answer.f1.calm.raw',
#        'Answer.f1.confused.raw', 'Answer.f1.disgusted.raw',
#        'Answer.f1.excited.raw', 'Answer.f1.frustrated.raw',
#        'Answer.f1.happy.raw', 'Answer.f1.jealous.raw',
#        'Answer.f1.nostalgic.raw', 'Answer.f1.proud.raw', 'Answer.f1.sad.raw',
#        'Answer.f1.satisfied.raw', 'Answer.f1.surprised.raw',
#        'Answer.t1.exercise.raw', 'Answer.t1.family.raw', 'Answer.t1.food.raw',
#        'Answer.t1.friends.raw', 'Answer.t1.god.raw', 'Answer.t1.health.raw',
#        'Answer.t1.love.raw', 'Answer.t1.recreation.raw',
#        'Answer.t1.school.raw', 'Answer.t1.sleep.raw', 'Answer.t1.work.raw'],
#       dtype='object')

# %%
# Assuming `df` is your DataFrame containing the columns
emotion_columns = [
    'Answer.f1.afraid.raw', 'Answer.f1.angry.raw', 'Answer.f1.anxious.raw',
    'Answer.f1.ashamed.raw', 'Answer.f1.awkward.raw', 'Answer.f1.bored.raw',
    'Answer.f1.calm.raw', 'Answer.f1.confused.raw', 'Answer.f1.disgusted.raw',
    'Answer.f1.excited.raw', 'Answer.f1.frustrated.raw', 'Answer.f1.happy.raw',
    'Answer.f1.jealous.raw', 'Answer.f1.nostalgic.raw', 'Answer.f1.proud.raw',
    'Answer.f1.sad.raw', 'Answer.f1.satisfied.raw', 'Answer.f1.surprised.raw'
]

# Calculate the count for each emotion
emotion_counts = df_journals[emotion_columns].sum()

# Convert to a DataFrame for easier viewing
emotion_counts_df = emotion_counts.reset_index()
emotion_counts_df.columns = ['Emotion', 'Count']

# Display the result
print(emotion_counts_df)
# Out:
#                      Emotion  Count
# 0       Answer.f1.afraid.raw     18
# 1        Answer.f1.angry.raw     28
# 2      Answer.f1.anxious.raw    125
# 3      Answer.f1.ashamed.raw     17
# 4      Answer.f1.awkward.raw     15
# 5        Answer.f1.bored.raw     49
# 6         Answer.f1.calm.raw    368
# 7     Answer.f1.confused.raw     28
# 8    Answer.f1.disgusted.raw     22
# 9      Answer.f1.excited.raw    251
# 10  Answer.f1.frustrated.raw    141
# 11       Answer.f1.happy.raw    730
# 12     Answer.f1.jealous.raw      3
# 13   Answer.f1.nostalgic.raw     61
# 14       Answer.f1.proud.raw    337
# 15         Answer.f1.sad.raw     43
# 16   Answer.f1.satisfied.raw    591
# 17   Answer.f1.surprised.raw     64

# %%
# Consolidating counts for each core emotion
core_emotions = {
    "Joy": [
        'Answer.f1.happy.raw', 'Answer.f1.satisfied.raw',
        'Answer.f1.proud.raw', 'Answer.f1.excited.raw', 'Answer.f1.calm.raw'
    ],
    "Disgust": [
        'Answer.f1.disgusted.raw', 'Answer.f1.jealous.raw',
        'Answer.f1.ashamed.raw'        
    ],
    "Anger": [
        'Answer.f1.frustrated.raw', 'Answer.f1.angry.raw'
        
    ],
    "Fear": [
        'Answer.f1.anxious.raw', 'Answer.f1.afraid.raw',
        'Answer.f1.awkward.raw', 'Answer.f1.confused.raw',
        'Answer.f1.surprised.raw'
    ],
    "Sadness": [
        'Answer.f1.sad.raw', 'Answer.f1.bored.raw',  
        'Answer.f1.nostalgic.raw'
    ]
}

consolidated_counts = {
    emotion: df_journals[columns].sum() for emotion, columns in core_emotions.items()
}

# Display results
for core_emotion, count in consolidated_counts.items():
    print(f"{core_emotion}: {count}")
# Out:
# Joy: Answer.f1.happy.raw        730
# Answer.f1.satisfied.raw    591
# Answer.f1.proud.raw        337
# Answer.f1.excited.raw      251
# Answer.f1.calm.raw         368
# dtype: int64
# Disgust: Answer.f1.disgusted.raw    22
# Answer.f1.jealous.raw       3
# Answer.f1.ashamed.raw      17
# dtype: int64
# Anger: Answer.f1.frustrated.raw    141
# Answer.f1.angry.raw          28
# dtype: int64
# Fear: Answer.f1.anxious.raw      125
# Answer.f1.afraid.raw        18
# Answer.f1.awkward.raw       15
# Answer.f1.confused.raw      28
# Answer.f1.surprised.raw     64
# dtype: int64
# Sadness: Answer.f1.sad.raw          43
# Answer.f1.bored.raw        49
# Answer.f1.nostalgic.raw    61
# dtype: int64

# %%
# Create a new DataFrame with journal entries and core emotion classifications
df_core_emotions = df_journals[['Answer']].copy()

# Add a column for each core emotion
for emotion, columns in core_emotions.items():
    # Check if any of the columns for the current emotion are True
    df_core_emotions[emotion] = df_journals[columns].any(axis=1)

# Display the new DataFrame
print(df_core_emotions)
# Out:
#                                                  Answer   Joy  Disgust  Anger  \
# 0     My family was the most salient part of my day,...  True    False  False
# 1     Yoga keeps me focused. I am able to take some ...  True    False  False
# 2     Yesterday, my family and I played a bunch of b...  True    False  False
# 3     Yesterday, I visited my parents and had dinner...  True    False  False
# 4     Yesterday, I really felt the importance of my ...  True    False  False
# ...                                                 ...   ...      ...    ...
# 1468  A workout, dining with friends makes for a hea...  True    False  False
# 1469  My connection to God, through prayer brings me...  True    False  False
# 1470  I got a skull pan for halloween, and my husban...  True    False  False
# 1471  I spoke over the phone with my brother that li...  True    False  False
# 1472  I had a lengthy but mostly fun, frivolous conv...  True    False  False
#
#        Fear  Sadness
# 0      True    False
# 1     False    False
# 2     False    False
# 3     False    False
# 4     False    False
# ...     ...      ...
# 1468  False    False
# 1469  False    False
# 1470  False    False
# 1471  False    False
# 1472  False    False
#
# [1473 rows x 6 columns]

# %%
# Count the frequency of each core emotion
emotion_frequencies = df_core_emotions[['Joy', 'Disgust', 'Anger', 'Fear', 'Sadness']].sum()

# Convert to a DataFrame for easier readability
emotion_frequencies_df = emotion_frequencies.reset_index()
emotion_frequencies_df.columns = ['Emotion', 'Frequency']

# Display the result
print(emotion_frequencies_df)
sum(emotion_frequencies_df['Frequency'])
# Out:
#    Emotion  Frequency
# 0      Joy       1252
# 1  Disgust         40
# 2    Anger        153
# 3     Fear        213
# 4  Sadness        148
# 1806

# %%
# Create a column representing the combination of emotions for each row
df_core_emotions['Emotion_Combination'] = df_core_emotions[['Joy', 'Disgust', 'Anger', 'Fear', 'Sadness']].apply(
    lambda row: ', '.join(row.index[row]), axis=1
)

# Count the frequency of each combination
combination_frequencies = df_core_emotions['Emotion_Combination'].value_counts()

# Convert to a DataFrame for better readability
combination_frequencies_df = combination_frequencies.reset_index()
combination_frequencies_df.columns = ['Emotion_Combination', 'Frequency']

# Display the result
print(combination_frequencies_df)
# Out:
#         Emotion_Combination  Frequency
# 0                       Joy       1078
# 1                 Joy, Fear         72
# 2              Joy, Sadness         60
# 3               Anger, Fear         42
# 4                      Fear         42
# 5                     Anger         39
# 6                   Sadness         24
# 7             Fear, Sadness         16
# 8      Anger, Fear, Sadness         16
# 9                Joy, Anger         14
# 10           Anger, Sadness         10
# 11                  Disgust          9
# 12         Joy, Anger, Fear          8
# 13      Joy, Anger, Sadness          7
# 14  Disgust, Anger, Sadness          6
# 15           Disgust, Anger          6
# 16       Joy, Fear, Sadness          5
# 17             Joy, Disgust          5
# 18     Disgust, Anger, Fear          5
# 19            Disgust, Fear          4
# 20    Joy, Disgust, Sadness          2
# 21   Disgust, Fear, Sadness          2
# 22       Joy, Disgust, Fear          1

# %%
df_core_emotions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1473 entries, 0 to 1472
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Answer               1473 non-null   object
#  1   Joy                  1473 non-null   bool
#  2   Disgust              1473 non-null   bool
#  3   Anger                1473 non-null   bool
#  4   Fear                 1473 non-null   bool
#  5   Sadness              1473 non-null   bool
#  6   Emotion_Combination  1473 non-null   object
# dtypes: bool(5), object(2)
# memory usage: 30.3+ KB

# %%
df_mentalhealth = pd.read_csv('https://media.githubusercontent.com/media/EthanRosehart/DS2_Assignments/refs/heads/main/students_mental_health.csv')

# %%
df_mentalhealth.head()
# Out:
#    Age            Course  Gender  CGPA  Stress_Level  Depression_Score  \
# 0   25            Others    Male  3.56             3                 3
# 1   24       Engineering  Female  2.44             0                 3
# 2   19          Business  Female  3.74             4                 0
# 3   19  Computer Science    Male  3.65             2                 1
# 4   18          Business    Male  3.40             3                 3
#
#    Anxiety_Score Sleep_Quality Physical_Activity Diet_Quality Social_Support  \
# 0              2          Good          Moderate         Good       Moderate
# 1              0       Average               Low      Average            Low
# 2              3          Good               Low      Average       Moderate
# 3              0       Average               Low      Average       Moderate
# 4              4          Good               Low      Average           High
#
#   Relationship_Status Substance_Use Counseling_Service_Use Family_History  \
# 0             Married         Never                  Never             No
# 1              Single  Occasionally           Occasionally             No
# 2   In a Relationship         Never           Occasionally             No
# 3              Single           NaN                  Never             No
# 4             Married         Never                  Never             No
#
#   Chronic_Illness  Financial_Stress Extracurricular_Involvement  \
# 0              No                 2                    Moderate
# 1              No                 3                         Low
# 2              No                 4                        High
# 3              No                 4                    Moderate
# 4             Yes                 0                        High
#
#    Semester_Credit_Load Residence_Type
# 0                    17      On-Campus
# 1                    27      On-Campus
# 2                    15      On-Campus
# 3                    20     Off-Campus
# 4                    23      On-Campus

# %%
df_mentalhealth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7022 entries, 0 to 7021
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age                          7022 non-null   int64
#  1   Course                       7022 non-null   object
#  2   Gender                       7022 non-null   object
#  3   CGPA                         7010 non-null   float64
#  4   Stress_Level                 7022 non-null   int64
#  5   Depression_Score             7022 non-null   int64
#  6   Anxiety_Score                7022 non-null   int64
#  7   Sleep_Quality                7022 non-null   object
#  8   Physical_Activity            7022 non-null   object
#  9   Diet_Quality                 7022 non-null   object
#  10  Social_Support               7022 non-null   object
#  11  Relationship_Status          7022 non-null   object
#  12  Substance_Use                7007 non-null   object
#  13  Counseling_Service_Use       7022 non-null   object
#  14  Family_History               7022 non-null   object
#  15  Chronic_Illness              7022 non-null   object
#  16  Financial_Stress             7022 non-null   int64
#  17  Extracurricular_Involvement  7022 non-null   object
#  18  Semester_Credit_Load         7022 non-null   int64
#  19  Residence_Type               7022 non-null   object
# dtypes: float64(1), int64(6), object(13)
# memory usage: 1.1+ MB

# %%
# Filter the mental health dataset
columns_to_keep = ['Age', 'Gender', 'CGPA', 'Stress_Level', 'Depression_Score',
                   'Anxiety_Score', 'Sleep_Quality', 'Physical_Activity', 'Diet_Quality',
                   'Relationship_Status', 'Financial_Stress']
df_mentalhealth_filtered = df_mentalhealth[columns_to_keep].copy()

# Add a Negative_Emotion indicator in df_core_emotions
negative_emotions = ['Disgust', 'Anger', 'Fear', 'Sadness']
df_core_emotions['Negative_Emotion'] = df_core_emotions[negative_emotions].any(axis=1)

# %%
df_core_emotions['Negative_Emotion'].value_counts()
# Out:
# Negative_Emotion
# False    1078
# True      395
# Name: count, dtype: int64

# %%
# Filter journal entries with and without negative emotions
negative_emotions = df_core_emotions[df_core_emotions['Negative_Emotion']]
positive_emotions = df_core_emotions[~df_core_emotions['Negative_Emotion']]

# Filter mental health dataset into higher and lower scores
higher_scores = df_mentalhealth_filtered[
    (df_mentalhealth_filtered['Depression_Score'] >= 3) & 
    (df_mentalhealth_filtered['Anxiety_Score'] >= 3)
]
lower_scores = df_mentalhealth_filtered[
    (df_mentalhealth_filtered['Depression_Score'] < 3) & 
    (df_mentalhealth_filtered['Anxiety_Score'] < 3)
]

# Filter journal entries with and without negative emotions
negative_emotions = df_core_emotions[df_core_emotions['Negative_Emotion']]
positive_emotions = df_core_emotions[~df_core_emotions['Negative_Emotion']]

# Filter mental health dataset into higher and lower scores
higher_scores = df_mentalhealth_filtered[
    (df_mentalhealth_filtered['Depression_Score'] >= 3) & 
    (df_mentalhealth_filtered['Anxiety_Score'] >= 3)
]
lower_scores = df_mentalhealth_filtered[
    (df_mentalhealth_filtered['Depression_Score'] < 3) & 
    (df_mentalhealth_filtered['Anxiety_Score'] < 3)
]

# Define the necessary columns to check for NULL values
necessary_columns = ['Age', 'Gender', 'CGPA', 'Stress_Level', 'Depression_Score',
                     'Anxiety_Score', 'Sleep_Quality', 'Physical_Activity', 'Diet_Quality',
                     'Relationship_Status', 'Financial_Stress']

# Create filtered versions of higher_scores and lower_scores without NULL values
higher_scores_filtered = higher_scores.dropna(subset=necessary_columns)
lower_scores_filtered = lower_scores.dropna(subset=necessary_columns)

# Ensure that the number of samples does not exceed the available data
num_negative = min(len(negative_emotions), len(higher_scores_filtered))
num_positive = min(len(positive_emotions), len(lower_scores_filtered))

# Sample from higher_scores_filtered for journal entries with negative emotions
sampled_higher_scores = higher_scores_filtered.sample(n=num_negative, random_state=42)

# Sample from lower_scores_filtered for journal entries without negative emotions
sampled_lower_scores = lower_scores_filtered.sample(n=num_positive, random_state=42)

# Introduce randomness: Swap some entries between higher and lower scores
swap_count = int(num_negative * 0.1)  # 10% randomness
swap_count = min(swap_count, len(sampled_higher_scores), len(sampled_lower_scores))

random_higher_to_lower = sampled_higher_scores.sample(n=swap_count, random_state=42)
random_lower_to_higher = sampled_lower_scores.sample(n=swap_count, random_state=42)

# Perform the swaps
sampled_higher_scores = pd.concat([
    sampled_higher_scores.drop(random_higher_to_lower.index),
    random_lower_to_higher
], ignore_index=True)

sampled_lower_scores = pd.concat([
    sampled_lower_scores.drop(random_lower_to_higher.index),
    random_higher_to_lower
], ignore_index=True)

# Combine journal entries with their corresponding scores
negative_combined = pd.concat([
    negative_emotions.reset_index(drop=True),
    sampled_higher_scores.reset_index(drop=True)
], axis=1)

positive_combined = pd.concat([
    positive_emotions.reset_index(drop=True),
    sampled_lower_scores.reset_index(drop=True)
], axis=1)

# Combine all entries into the final dataset
df_final = pd.concat([negative_combined, positive_combined]).reset_index(drop=True)

# Retain necessary columns and drop rows with any NULL values
final_columns = ['Answer', 'Age', 'Gender', 'CGPA', 'Stress_Level', 'Depression_Score',
                 'Anxiety_Score', 'Sleep_Quality', 'Physical_Activity', 'Diet_Quality',
                 'Relationship_Status', 'Financial_Stress', 'Negative_Emotion']
df_final = df_final[final_columns].dropna()

# Display the final DataFrame
print(df_final)
# Out:
#                                                  Answer  Age  Gender  CGPA  \
# 0     My family was the most salient part of my day,...   26    Male  3.06
# 1     Yesterday, I had to go to work. It was my firs...   34    Male  3.25
# 2     Yesterday, I got a lot of things ready for lis...   27  Female  3.80
# 3     Yesterday was my birthday and I spent it with ...   19  Female  3.90
# 4     Yesterday was a bad day for diverticular disea...   25    Male  3.08
# ...                                                 ...  ...     ...   ...
# 1468  A workout, dining with friends makes for a hea...   22  Female  3.32
# 1469  My connection to God, through prayer brings me...   20  Female  3.80
# 1470  I got a skull pan for halloween, and my husban...   23    Male  3.83
# 1471  I spoke over the phone with my brother that li...   21    Male  3.97
# 1472  I had a lengthy but mostly fun, frivolous conv...   24  Female  3.60
#
#       Stress_Level  Depression_Score  Anxiety_Score Sleep_Quality  \
# 0                3                 5              3          Good
# 1                0                 4              3       Average
# 2                5                 4              4          Good
# 3                5                 3              3       Average
# 4                5                 3              5       Average
# ...            ...               ...            ...           ...
# 1468             5                 4              5          Good
# 1469             3                 4              3          Poor
# 1470             5                 3              4          Poor
# 1471             0                 3              3       Average
# 1472             1                 3              4       Average
#
#      Physical_Activity Diet_Quality Relationship_Status  Financial_Stress  \
# 0             Moderate         Good             Married                 0
# 1                  Low      Average              Single                 2
# 2             Moderate         Poor   In a Relationship                 0
# 3             Moderate      Average              Single                 1
# 4             Moderate      Average              Single                 3
# ...                ...          ...                 ...               ...
# 1468               Low         Poor              Single                 5
# 1469          Moderate         Poor              Single                 3
# 1470               Low      Average             Married                 0
# 1471          Moderate      Average              Single                 0
# 1472          Moderate         Good              Single                 2
#
#       Negative_Emotion
# 0                 True
# 1                 True
# 2                 True
# 3                 True
# 4                 True
# ...                ...
# 1468             False
# 1469             False
# 1470             False
# 1471             False
# 1472             False
#
# [1473 rows x 13 columns]

# %%
# Generate a unique 9-digit Student ID for each entry using permutation
np.random.seed(42)  # For reproducibility
student_ids = np.random.permutation(range(100000000, 100000000 + len(df_final)))
df_final['Student_ID'] = student_ids

# Rearrange columns to place Student_ID at the front
columns_order = ['Student_ID'] + [col for col in df_final.columns if col != 'Student_ID']
df_final = df_final[columns_order]

# %%
# Assign absences and lates based on depression and anxiety scores
def generate_absences_and_lates(row, max_absences=15, max_lates=10):
    mean_score = (row['Depression_Score'] + row['Anxiety_Score']) / 2
    base_absences = int(mean_score / 5 * max_absences)  # Scale absences based on scores
    base_lates = int(mean_score / 5 * max_lates)  # Scale lates based on scores

    # Introduce randomness (10%)
    absences = np.random.randint(base_absences - 2, base_absences + 3)
    lates = np.random.randint(base_lates - 1, base_lates + 2)

    # Ensure absences and lates are non-negative
    absences = max(absences, 0)
    lates = max(lates, 0)

    return absences, lates

# Apply the function to generate absences and lates
df_final[['Absences', 'Lates']] = df_final.apply(
    lambda row: pd.Series(generate_absences_and_lates(row)), axis=1
)

# Add At Risk column
df_final['At_Risk'] = ((df_final['Depression_Score'] + df_final['Anxiety_Score']) / 2 >= 3).astype(int)

# Export to CSV
output_path = "final_dataset.csv"
df_final.to_csv(output_path, index=False)

print(f"Dataset exported to {output_path}")
# Out:
# Dataset exported to final_dataset.csv

# %%
import os
print("Current Working Directory:", os.getcwd())
# Out:
# Current Working Directory: C:\Users\etjdr\AppData\Local\Programs\Microsoft VS Code

# %%
df = pd.read_csv('https://media.githubusercontent.com/media/EthanRosehart/DS2_Assignments/refs/heads/main/final_dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1473 entries, 0 to 1472
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Student_ID           1473 non-null   int64
#  1   Answer               1473 non-null   object
#  2   Age                  1473 non-null   int64
#  3   Gender               1473 non-null   object
#  4   CGPA                 1473 non-null   float64
#  5   Stress_Level         1473 non-null   int64
#  6   Depression_Score     1473 non-null   int64
#  7   Anxiety_Score        1473 non-null   int64
#  8   Sleep_Quality        1473 non-null   object
#  9   Physical_Activity    1473 non-null   object
#  10  Diet_Quality         1473 non-null   object
#  11  Relationship_Status  1473 non-null   object
#  12  Financial_Stress     1473 non-null   int64
#  13  Negative_Emotion     1473 non-null   bool
#  14  Absences             1473 non-null   int64
#  15  Lates                1473 non-null   int64
#  16  At_Risk              1473 non-null   int64
# dtypes: bool(1), float64(1), int64(9), object(6)
# memory usage: 185.7+ KB

# %%
# Check the first few rows
print(df.head())

# Verify uniqueness of Student_ID
print("Unique Student_IDs:", df['Student_ID'].nunique() == len(df))

# Check At_Risk column logic
at_risk_check = ((df['Depression_Score'] + df['Anxiety_Score']) / 2 >= 3).astype(int)
print("At_Risk column correct:", (df['At_Risk'] == at_risk_check).all())
# Out:
#    Student_ID                                             Answer  Age  Gender  \
# 0   100000852  My family was the most salient part of my day,...   26    Male
# 1   100000184  Yesterday, I had to go to work. It was my firs...   34    Male
# 2   100001261  Yesterday, I got a lot of things ready for lis...   27  Female
# 3   100000067  Yesterday was my birthday and I spent it with ...   19  Female
# 4   100000220  Yesterday was a bad day for diverticular disea...   25    Male
#
#    CGPA  Stress_Level  Depression_Score  Anxiety_Score Sleep_Quality  \
# 0  3.06             3                 5              3          Good
# 1  3.25             0                 4              3       Average
# 2  3.80             5                 4              4          Good
# 3  3.90             5                 3              3       Average
# 4  3.08             5                 3              5       Average
#
#   Physical_Activity Diet_Quality Relationship_Status  Financial_Stress  \
# 0          Moderate         Good             Married                 0
# 1               Low      Average              Single                 2
# 2          Moderate         Poor   In a Relationship                 0
# 3          Moderate      Average              Single                 1
# 4          Moderate      Average              Single                 3
#
#    Negative_Emotion  Absences  Lates  At_Risk
# 0              True        14      8        1
# 1              True         8      6        1
# 2              True        12      8        1
# 3              True         7      5        1
# 4              True        12      8        1
# Unique Student_IDs: True
# At_Risk column correct: True

# %%
print(df[['Absences', 'Lates']].describe())
# Out:
#           Absences        Lates
# count  1473.000000  1473.000000
# mean      5.148676     3.536320
# std       4.234983     2.820527
# min       0.000000     0.000000
# 25%       2.000000     1.000000
# 50%       4.000000     3.000000
# 75%       8.000000     5.000000
# max      17.000000    11.000000
